# %%
import numpy as np

# %%
np.__version__
# Out:
# '1.19.2'

# %%
np.zeros()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-f08d7517924f> in <module>
# ----> 1 np.zeros()
#
# TypeError: zeros() missing required argument 'shape' (pos 1)
